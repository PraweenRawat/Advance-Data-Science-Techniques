# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
from sklearn.preprocessing import MinMaxScaler

# %%
data = {
    'Age' : [25,45,31,52,22]
}

# %%
df = pd.DataFrame(data)
print(df)
scaler = MinMaxScaler()
# Out:
#    Age
# 0   25
# 1   45
# 2   31
# 3   52
# 4   22

# %%
df['age']=scaler.fit_transform(df)

# %%
df
# Out:
#    Age       age
# 0   25  0.100000
# 1   45  0.766667
# 2   31  0.300000
# 3   52  1.000000
# 4   22  0.000000
